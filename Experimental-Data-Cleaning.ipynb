# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
from myToolBox import create_stat_df, get_attributes_type, count_isolated, count_distinct

# %% [markdown]
# # Dataset-1

# %%
dataset_folder = 'dataset-1/'
dataset_path = dataset_folder + 'load.data'
attributes_path = dataset_folder + 'attributes.txt'

# Get all the attributes
attributes_type = get_attributes_type(attributes_path,
                                      numeric_term='continuous')

data = pd.read_csv(dataset_path,header=None, names=list(attributes_type.keys()))
len(data.columns)
# Out:
# 26

# %%
# Edit number in head() to show more or less
create_stat_df(data, attributes_type)
# Out:
#             Attribute  Data type Mean/Distinct values  Std/Isolated values  \
# 0           symboling    nominal                    6                    0
# 1   normalized-losses  numerical               122.00                35.33
# 2                make    nominal                   22                    1
# 3           fuel-type    nominal                    2                    0
# 4          aspiration    nominal                    2                    0
# 5        num-of-doors    nominal                    2                    0
# 6          body-style    nominal                    5                    0
# 7        drive-wheels    nominal                    3                    0
# 8     engine-location    nominal                    2                    0
# 9          wheel-base  numerical                98.76                 6.01
# 10             length  numerical               174.05                12.31
# 11              width  numerical                65.91                 2.14
# 12             height  numerical                53.72                 2.44
# 13        curb-weight  numerical              2555.57               519.41
# 14        engine-type    nominal                    7                    1
# 15   num-of-cylinders    nominal                    7                    2
# 16        engine-size  numerical               126.91                41.54
# 17        fuel-system    nominal                    8                    2
# 18               bore  numerical                 3.33                 0.27
# 19             stroke  numerical                 3.26                 0.32
# 20  compression-ratio  numerical                10.14                 3.96
# 21         horsepower  numerical               104.26                39.62
# 22           peak-rpm  numerical              5125.37               478.15
# 23           city-mpg  numerical                25.22                 6.53
# 24        highway-mpg  numerical                30.75                 6.87
# 25              price  numerical             13207.13              7927.27
#
#    Num of Nulls
# 0     0 (0.00%)
# 1   41 (20.00%)
# 2     0 (0.00%)
# 3     0 (0.00%)
# 4     0 (0.00%)
# 5     2 (0.98%)
# 6     0 (0.00%)
# 7     0 (0.00%)
# 8     0 (0.00%)
# 9     0 (0.00%)
# 10    0 (0.00%)
# 11    0 (0.00%)
# 12    0 (0.00%)
# 13    0 (0.00%)
# 14    0 (0.00%)
# 15    0 (0.00%)
# 16    0 (0.00%)
# 17    0 (0.00%)
# 18    4 (1.95%)
# 19    4 (1.95%)
# 20    0 (0.00%)
# 21    2 (0.98%)
# 22    2 (0.98%)
# 23    0 (0.00%)
# 24    0 (0.00%)
# 25    4 (1.95%)

# %% [markdown]
# # Dataset 2

# %%
dataset_folder = 'dataset-2/'
dataset_path = dataset_folder + 'load.data'
attributes_path = dataset_folder + 'attributes.txt'

# Get all the attributes
attributes_type = get_attributes_type(attributes_path,
                                      numeric_term='numeric')

data = pd.read_csv(dataset_path,header=None, names=list(attributes_type.keys()))

# %%
# Edit number in head() to show more or less
create_stat_df(data,attributes_type)
# Out:
#               Attribute  Data type Mean/Distinct values  Std/Isolated values  \
# 0             timestamp    nominal                  297                  162
# 1       cylinder-number    nominal                  434                  350
# 2              customer    nominal                   84                   19
# 3            job-number    nominal                  262                  117
# 4        grain-screened    nominal                    3                    1
# 5             ink-color    nominal                    4                    1
# 6      proof-on-ctd-ink    nominal                    3                    1
# 7             blade-mfg    nominal                    3                    2
# 8     cylinder-division    nominal                    3                    1
# 9            paper-type    nominal                    6                    1
# 10             ink-type    nominal                    6                    0
# 11         direct-steam    nominal                    4                    1
# 12         solvent-type    nominal                    3                    0
# 13     type-on-cylinder    nominal                    4                    0
# 14           press-type    nominal                    4                    0
# 15                press    nominal                    8                    0
# 16          unit-number    nominal                    8                    1
# 17        cylinder-size    nominal                    8                    2
# 18  paper-mill-location    nominal                    7                    2
# 19         plating-tank    nominal                    4                    2
# 20            proof-cut  numerical                45.17                 9.48
# 21            viscosity  numerical                51.03                 8.27
# 22              caliper  numerical                 0.28                 0.07
# 23      ink-temperature  numerical                15.36                 1.28
# 24             humifity  numerical                78.54                 7.73
# 25            roughness  numerical                 0.72                 0.19
# 26       blade-pressure  numerical                30.91                 9.11
# 27          varnish-pct  numerical                 5.78                 6.84
# 28          press-speed  numerical              1823.36               328.40
# 29              ink-pct  numerical                55.64                 5.56
# 30          solvent-pct  numerical                38.57                 3.50
# 31          ESA-Voltage  numerical                 1.32                 2.46
# 32         ESA-Amperage  numerical                 0.04                 0.42
# 33                  wax  numerical                 2.40                 0.55
# 34             hardener  numerical                 0.99                 0.37
# 35     roller-durometer  numerical                34.78                 4.50
# 36      current-density  numerical                39.06                 2.35
# 37    anode-space-ratio  numerical               103.03                 5.00
# 38       chrome-content  numerical                99.60                 1.85
# 39            band-type    nominal                    3                    0
#
#     Num of Nulls
# 0      0 (0.00%)
# 1      1 (0.18%)
# 2      0 (0.00%)
# 3      1 (0.18%)
# 4     49 (9.06%)
# 5      0 (0.00%)
# 6    57 (10.54%)
# 7    60 (11.09%)
# 8      0 (0.00%)
# 9      0 (0.00%)
# 10     1 (0.18%)
# 11    25 (4.62%)
# 12   56 (10.35%)
# 13    19 (3.51%)
# 14     1 (0.18%)
# 15     1 (0.18%)
# 16     0 (0.00%)
# 17     3 (0.55%)
# 18  156 (28.84%)
# 19    18 (3.33%)
# 20    54 (9.98%)
# 21     5 (0.92%)
# 22    27 (4.99%)
# 23     2 (0.37%)
# 24     1 (0.18%)
# 25    30 (5.55%)
# 26   63 (11.65%)
# 27   55 (10.17%)
# 28    10 (1.85%)
# 29   55 (10.17%)
# 30   55 (10.17%)
# 31   56 (10.35%)
# 32    54 (9.98%)
# 33     6 (1.11%)
# 34     7 (1.29%)
# 35    54 (9.98%)
# 36     7 (1.29%)
# 37     7 (1.29%)
# 38     3 (0.55%)
# 39     0 (0.00%)

# %%
dataset_folder = 'dataset-3/'
dataset_path = dataset_folder + 'load.data'
attributes_path = dataset_folder + 'attributes.txt'

# Get all the attributes
attributes_type = get_attributes_type(attributes_path,
                                      numeric_term='numerical')

data = pd.read_csv(dataset_path,header=None, names=list(attributes_type.keys()))

# %%
# Edit number in head() to show more or less
create_stat_df(data,attributes_type)
# Out:
#                       Attribute  Data type Mean/Distinct values  \
# 0            Sample-code-number    nominal                  645
# 1               Clump-Thickness  numerical                 4.42
# 2       Uniformity-of-Cell-Size  numerical                 3.13
# 3      Uniformity-of-Cell-Shape  numerical                 3.21
# 4             Marginal-Adhesion  numerical                 2.81
# 5   Single-Epithelial-Cell-Size  numerical                 3.22
# 6                   Bare-Nuclei  numerical                 3.54
# 7               Bland-Chromatin  numerical                 3.44
# 8               Normal-Nucleoli  numerical                 2.87
# 9                       Mitoses  numerical                 1.59
# 10                        Class    nominal                    2
#
#     Std/Isolated values Num of Nulls
# 0                   599    0 (0.00%)
# 1                  2.81    0 (0.00%)
# 2                  3.05    0 (0.00%)
# 3                  2.97    0 (0.00%)
# 4                  2.85    0 (0.00%)
# 5                  2.21    0 (0.00%)
# 6                  3.64   16 (2.29%)
# 7                  2.44    0 (0.00%)
# 8                  3.05    0 (0.00%)
# 9                  1.71    0 (0.00%)
# 10                    0    0 (0.00%)
